# %% [markdown]
# # Apply the Clustering algorithms to the dimensionality reduction datasets

# %% [markdown]
# ## Social Media and Mental Health

# %% [markdown]
# ### 1. ICA

# %%
# %run ../task1/clustering.py ../task2/insurance_ica_results.csv ../task2/smmh_ica_results.csv
# Out:
# K-Means Clustering on Insurance Dataset took 0.0089 seconds
# K-Means Clustering on SMMH Dataset took 0.0102 seconds
# EM Clustering on Insurance Dataset took 0.0136 seconds
# EM Clustering on SMMH Dataset took 0.0203 seconds

# %% [markdown]
# ### 2. PCA

# %%
# %run clustering.py ../task2/insurance_pca_results.csv ../task2/smmh_pca_results.csv
# Out:
# K-Means Clustering on Insurance Dataset took 0.0052 seconds
# K-Means Clustering on SMMH Dataset took 0.0080 seconds
# EM Clustering on Insurance Dataset took 0.0168 seconds
# EM Clustering on SMMH Dataset took 0.0275 seconds

# %% [markdown]
# ### 3. Randomized Projections

# %%
# %run clustering.py ../task2/insurance_randomized_projections.csv ../task2/smmh_randomized_projections.csv
# Out:
# K-Means Clustering on Insurance Dataset took 0.0099 seconds
# K-Means Clustering on SMMH Dataset took 0.0076 seconds
# EM Clustering on Insurance Dataset took 0.0237 seconds
# EM Clustering on SMMH Dataset took 0.0282 seconds
