# %% [markdown]
# # Add New Features and Run Neural Network

# %% [markdown]
# ## 1. Add New Features

# %%
# %run add_clusters.py ../datasets/smmh.csv
# Out:
# The new dataset with clusters has been saved as smmh_with_clusters.csv

# %% [markdown]
# ## 2. Run Neural Network

# %%
# %run ../task4/neural_network.py smmh_with_clusters.csv
# Out:
# Neural Network Classifier Training Time: 0.13 seconds
# Neural Network Classifier Training Accuracy: 0.46
# Neural Network Classifier Testing Accuracy: 0.30
# Neural Network Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.29      0.09      0.14        22
#            1       1.00      0.11      0.19        19
#            2       0.00      0.00      0.00        20
#            3       1.00      0.00      0.00         5
#            4       0.33      0.40      0.36         5
#            5       0.29      0.88      0.43        26
#
#     accuracy                           0.30        97
#    macro avg       0.48      0.25      0.19        97
# weighted avg       0.41      0.30      0.20        97
#
# ---------------------------------------------
