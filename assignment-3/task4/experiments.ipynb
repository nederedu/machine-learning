# %% [markdown]
# # 1. Apply the Clustering algorithms to each of the datasets

# %%
# %run neural_network.py ../datasets/smmh.csv
# Out:
# Neural Network Classifier Training Time: 0.22 seconds
# Neural Network Classifier Training Accuracy: 0.45
# Neural Network Classifier Testing Accuracy: 0.21
# Neural Network Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       1.00      0.00      0.00        19
#            2       0.00      0.00      0.00        20
#            3       0.00      0.00      0.00         5
#            4       0.25      0.20      0.22         5
#            5       0.23      0.73      0.36        26
#
#     accuracy                           0.21        97
#    macro avg       0.25      0.16      0.10        97
# weighted avg       0.27      0.21      0.11        97
#
# ---------------------------------------------
