# %% [markdown]
# # 4-Peaks with Insurance Data
#
# Results: age, BMI, smoker, region, children
#
# Hypothesis:
#
# Best Algorithm: Genetic

# %%
# %run 4-peaks-problem-size-4.py
# Out:
# Randomized Hill Climbing:
# Best state (encoded): [0 0 0 0]
# Best state (mapped): [18.0, 15.0, 0, 0]
# Best fitness: 8.1
# Function Evaluations: 604
# Wall Clock Time (s): 0.5470733642578125
# ----------------------------------------
# Simulated Annealing:
# Best state (encoded): [0 0 0 0]
# Best state (mapped): [18.0, 15.0, 0, 0]
# Best fitness: 8.1
# Function Evaluations: 703
# Wall Clock Time (s): 0.017818212509155273
# ----------------------------------------
# Genetic Algorithm:
# Best state (encoded): [0 0 0 0]
# Best state (mapped): [18.0, 15.0, 0, 0]
# Best fitness: 8.1
# Function Evaluations: 134
# Wall Clock Time (s): 1.489161729812622
# ----------------------------------------
# MIMIC:
# Best state (encoded): [0 0 0 1]
# Best state (mapped): [18.0, 15.0, 0, 1]
# Best fitness: 8.2
# Function Evaluations: 101
# Wall Clock Time (s): 0.9789388179779053
# ----------------------------------------

# %%
# %run 4-peaks-problem-size-5.py
# Out:
# Randomized Hill Climbing:
# Best state (encoded): [0 0 0 0 0]
# Best state (mapped): [18.0, 15.0, 0, 0, 0]
# Best fitness: 8.1
# Function Evaluations: 211
# Wall Clock Time (s): 0.07433962821960449
# ----------------------------------------
# Simulated Annealing:
# Best state (encoded): [0 0 0 1 0]
# Best state (mapped): [18.0, 15.0, 0, 1, 0]
# Best fitness: 8.2
# Function Evaluations: 494
# Wall Clock Time (s): 0.032918453216552734
# ----------------------------------------
# Genetic Algorithm:
# Best state (encoded): [0 0 0 0 0]
# Best state (mapped): [18.0, 15.0, 0, 0, 0]
# Best fitness: 8.1
# Function Evaluations: 119
# Wall Clock Time (s): 2.575397491455078
# ----------------------------------------
# MIMIC:
# Best state (encoded): [0 0 0 0 0]
# Best state (mapped): [18.0, 15.0, 0, 0, 0]
# Best fitness: 8.1
# Function Evaluations: 102
# Wall Clock Time (s): 2.8216569423675537
# ----------------------------------------
